# %%
pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.3 MB 2.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 60.2 MB/s
# ...
#      |████████████████████████████████| 237 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 164 kB 57.6 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 38.4 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 51 kB 6.4 MB/s
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=5294fcbc723b54a2ffe09d9a7e8aa22eaaef2d237393bb12beb4dd54dd3ee536
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# ...

# %%
pip install glob2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import glob
import librosa
import librosa.display as ipd

import numpy as np
import matplotlib.pyplot as plt
import streamlit as st

# %%
# %%sh
# wget https://commonvoice.mozilla.org/en/datasets/cv-corpus-11.0-delta-2022-09-21/cv-corpus-11.0-delta-2022-09-21-en.tar.gz
# Out:
# --2022-11-30 05:12:37--  https://commonvoice.mozilla.org/en/datasets/cv-corpus-11.0-delta-2022-09-21/cv-corpus-11.0-delta-2022-09-21-en.tar.gz
# Resolving commonvoice.mozilla.org (commonvoice.mozilla.org)... 54.148.231.89, 34.215.8.158, 35.167.8.104
# Connecting to commonvoice.mozilla.org (commonvoice.mozilla.org)|54.148.231.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5199 (5.1K) [text/html]
# Saving to: ‘cv-corpus-11.0-delta-2022-09-21-en.tar.gz’
#
#      0K .....                                                 100%  930M=0s
#
# 2022-11-30 05:12:37 (930 MB/s) - ‘cv-corpus-11.0-delta-2022-09-21-en.tar.gz’ saved [5199/5199]

# %%
ls
# Out:
# cv-corpus-11.0-delta-2022-09-21-en.tar.gz  drive/
# cv-corpus-11-en/                           sample_data/

# %%
ls -lh
# Out:
# total 12K
# -rw-r--r-- 1 root root 5.1K Nov 28 16:08 cv-corpus-11.0-delta-2022-09-21-en.tar.gz
# drwxr-xr-x 1 root root 4.0K Nov 22 00:14 sample_data/

# %%
# Wave Plot for audio file in dataset

filename='cv-corpus-11-en/common_voice_en_33152278.mp3'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
print(filename)
librosa.display.waveplot(data,sr=sample_rate)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# cv-corpus-11-en/common_voice_en_33152278.mp3

# %% [markdown]
# # Wave Plot for first ten audio files in dataset

# %%
# Wave Plot for first ten audio files in dataset

import os

directoryName = 'cv-corpus-11-en'
for filenm in os.listdir('cv-corpus-11-en'):
    f = os.path.join(directoryName, filenm)
    plt.figure(figsize=(14,5))
    data,sample_rate=librosa.load(f)
    librosa.display.waveplot(data,sr=sample_rate)
    print(filenm)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# common_voice_en_33152290.mp3
# common_voice_en_33152280.mp3
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# common_voice_en_33152278.mp3
# common_voice_en_33152281.mp3
# ...

# %%
sample_rate
# Out:
# 22050

# %% [markdown]
# # Linear Scale Spectrogram

# %%
filename='cv-corpus-11-en/common_voice_en_33152278.mp3'
data,sample_rate=librosa.load(filename)
print(filename)

s_db = librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max)

fig, ax = plt.subplots()
img = librosa.display.specshow(s_db, x_axis='time', y_axis='linear', ax=ax)
ax.set(title='Linear-scale spectrogram')
fig.colorbar(img, ax=ax, format="%+2.f dB")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# cv-corpus-11-en/common_voice_en_33152278.mp3

# %%
import os

directoryName = 'cv-corpus-11-en'
for filenm in os.listdir('cv-corpus-11-en'):
    f = os.path.join(directoryName, filenm)
    plt.figure(figsize=(14,5))
    data,sample_rate=librosa.load(f)
    s_db = librosa.amplitude_to_db(np.abs(librosa.stft(data)),
                                       ref=np.max) 
    fig, ax = plt.subplots()
    img = librosa.display.specshow(s_db, x_axis='time', y_axis='linear', ax=ax)
    ax.set(title='Linear-scale spectrogram')
    fig.colorbar(img, ax=ax, format="%+2.f dB")   
    print(filenm)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# common_voice_en_33152290.mp3
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# common_voice_en_33152280.mp3
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# common_voice_en_33152278.mp3
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# common_voice_en_33152281.mp3
# ...
